# %%
from pydataset import data
df = data('quakes')
#data() # list all data sets

# %%
df.head()
# Out:
#      lat    long  depth  mag  stations
# 1 -20.42  181.62    562  4.8        41
# 2 -20.62  181.03    650  4.2        15
# 3 -26.00  184.10     42  5.4        43
# 4 -17.97  181.66    626  4.1        19
# 5 -20.42  181.96    649  4.0        11

# %%
df['c']=df.mag.astype(int)

# %%
df.mag.describe()
# Out:
# count    1000.000000
# mean        4.620400
# std         0.402773
# min         4.000000
# 25%         4.300000
# 50%         4.600000
# 75%         4.900000
# max         6.400000
# Name: mag, dtype: float64

# %%
df.category = df.mag.astype(int)

# %%
df.plot(kind='scatter',x='depth', y='mag')

# %%
df.plot.scatter(x='stations',y='mag', c=df.category, s=df.depth, alpha=.5)

# %%
df.plot.hist()

# %%
from pandas.tools.plotting import scatter_matrix
scatter_matrix(df, alpha=0.2, figsize=(12, 12), diagonal='hist')
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x10b69b990>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x10cecc1d0>]], dtype=object)

# %%
# %env
# Out:
# {'Apple_PubSub_Socket_Render': '/private/tmp/com.apple.launchd.7agb9X9B7D/Render',
#  'CLICOLOR': '1',
#  'DISPLAY': '/private/tmp/com.apple.launchd.UtTDPStfQ6/org.macosforge.xquartz:0',
#  'GIT_PAGER': 'cat',
#  'HOME': '/Users/sz',
#  'JPY_PARENT_PID': '12815',
#  'LANG': 'en_US.UTF-8',
#  'LOGNAME': 'sz',
#  'PAGER': 'cat',
#  'PATH': '/Users/sz/anaconda/bin:/Users/sz/anaconda/bin:/usr/local/bin:/usr/bin:/bin:/usr/sbin:/sbin:/opt/X11/bin',
#  'PWD': '/Users/sz',
#  'SHELL': '/bin/bash',
#  'SHLVL': '1',
#  'SSH_AUTH_SOCK': '/private/tmp/com.apple.launchd.0v6gDyNE6r/Listeners',
#  'TERM': 'xterm-color',
#  'TERM_PROGRAM': 'Apple_Terminal',
#  'TERM_PROGRAM_VERSION': '343.7',
#  'TERM_SESSION_ID': '2C430C8E-4465-41E5-BEC0-8141960EAF9D',
#  'TMPDIR': '/var/folders/6n/15bqj_qs7jn0ks2jcmlyb1w40000gn/T/',
#  'USER': 'sz',
#  'XPC_FLAGS': '0x0',
#  'XPC_SERVICE_NAME': '0',
#  '_': '/Users/sz/anaconda/bin/jupyter',
#  '__CF_USER_TEXT_ENCODING': '0x1F5:0x0:0x0'}
